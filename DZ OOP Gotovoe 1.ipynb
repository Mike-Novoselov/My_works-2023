# %%
class Student:
    def __init__(self, name, surname, gender):
        self.name = name
        self.surname = surname
        self.gender = gender
        self.finished_courses = []
        self.courses_in_progress = []
        self.grades = {}

    def rate_lecturer(self, teacher, course, grade):
        if isinstance(teacher, Lecturer) and course in teacher.courses_attached and course in self.courses_in_progress and 0 < grade <= 10:
            if course in teacher.grades:
                teacher.grades[course] += [grade]
            else:
                teacher.grades[course] = [grade]
        else:
            return "Ошибка"

    # def average_grades_hw(self):  # Подсчет средней оценки за д/з
    #     total = 0
    #     counter = 0
    #     for key, value in self.grades.items():
    #         for grades in value:
    #             total += grades
    #             counter += 1
    #     return round(total / counter, 1)
    def average_grades_hw(self):
        if not self.grades:
            return 0
        hw_grades = []
        for grade in self.grades.values():
            hw_grades.extend(grade)
        return round(sum(hw_grades) / len(hw_grades), 2)


    def __str__(self):
        res = f"Имя: {self.name} \n" \
              f"Фамилия: {self.surname} \n" \
              f"Средняя оценка за домашние задания: {self.average_grades_hw()} \n" \
              f"Курсы в процессе изучения: {self.courses_in_progress} \n" \
              f"Завершенные курсы: {self.finished_courses}"
        return res

    def add_courses(self, course_name):
        self.finished_courses.append(course_name)

    # def __eq__(self, other):
    #     """Метод сравнения объектов между собой"""
    #     if not isinstance(other, Student):
    #         print("Not a Student")
    #         return
    #     return self.average_grades_hw() == other.average_grades_hw()
    def __eq__(self, other):
        """Метод сравнения объектов между собой"""
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades_hw() == other.average_grades_hw()


    # def __gt__(self, other):
    #     """Метод сравнения объектов между собой"""
    #     if not isinstance(other, Student):
    #         print("Not a Student")
    #         return
    #     return self.average_grades_hw() > other.average_grades_hw()
    def __gt__(self, other):
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades_hw() > other.average_grades_hw()


    # def __lt__(self, other):
    #     """Метод сравнения объектов между собой"""
    #     if isinstance(other, Student):
    #         print("Not a Student")
    #         return
    #     raise self.average_grades_hw() < other.average_grades_hw()
    def __lt__(self, other):
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades_hw() < other.average_grades_hw()


    # def __le__(self, other):
    #     """Метод сравнения объектов между собой"""
    #     if isinstance(other, Student):
    #         print("Not a Student")
    #         return
    #     raise self.average_grades_hw() <= other.average_grades_hw()
    def __le__(self, other):
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades_hw() <= other.average_grades_hw()


class Mentor:
    def __init__(self, name, surname):
        self.name = name
        self.surname = surname
        self.courses_attached = []


class Lecturer(Mentor):
    def __init__(self, name, surname):
        super().__init__(name, surname)
        self.grades = {}

    # def average_grades(self):  # Подсчет средней оценки за лекции
    #     total = 0
    #     counter = 0
    #     for key, value in self.grades.items():
    #         for grades in value:
    #             total += grades
    #             counter += 1
    #     return round(total / counter, 1)
    def average_grades(self):
        if not self.grades:
            return 0
        all_grades = []
        for grade in self.grades.values():
            all_grades.extend(grade)
        return round(sum(all_grades) / len(all_grades), 2)


    def __str__(self):
        res = f"Имя: {self.name} \n" \
              f"Фамилия: {self.surname} \n" \
              f"Средняя оценка за лекции: {self.average_grades()}"
        return res

    # def __eq__(self, other):
    #     if not isinstance(other, Lecturer):
    #         print("Not a Lecturer")
    #         return
    #     return self.average_grades() == other.average_grades()
    def __eq__(self, other):
        """Метод сравнения объектов между собой"""
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades() == other.average_grades()

    # def __gt__(self, other):
    #     if not isinstance(other, Lecturer):
    #         print("Not a Lecturer")
    #         return
    #     return self.average_grades() > other.average_grades()
    def __gt__(self, other):
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades() > other.average_grades()
# ________________________________________________________________________________________________________________
    def __le__(self, other):
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades() <= other.average_grades()

    def __lt__(self, other):
        if not isinstance(other, self.__class__):
            raise Exception(f'{other} не является экземпляром класса {self.__class__}')
        return self.average_grades() < other.average_grades()


class Reviewer(Mentor):
    def rate_hw(self, student, course, grade):
        if isinstance(student, Student) and course in self.courses_attached and course in student.courses_in_progress and 0 < grade <= 10:
            if course in student.grades:
                student.grades[course] += [grade]
            else:
                student.grades[course] = [grade]
        else:
            return 'Ошибка'

    def __str__(self):
        res = f"Имя: {self.name} \n" \
              f"Фамилия: {self.surname}"
        return res

# ______________________________________________________________________________________________
# Создадим по 2 экземпляра для каждого класса
best_student = Student('Mick', 'Jagger', 'M')  # Студент №1
best_student.courses_in_progress += ['Python']
best_student.courses_in_progress += ["Введение"]
best_student.finished_courses += ["Git"]

worst_student = Student("Marilyn", "Manson", "M")  # Студент №2
worst_student.courses_in_progress += ['Python']
worst_student.courses_in_progress += ["Введение"]
worst_student.finished_courses += ["Git"]

cool_lecturer = Lecturer('Till', 'Lindemann')  # Лектор №1
cool_lecturer.courses_attached += ['Python']
cool_lecturer.courses_attached += ['Введение']
cool_lecturer.courses_attached += ["Git"]

bad_lecturer = Lecturer("Kurt", "Cobain")  # Лектор №2
bad_lecturer.courses_attached += ['Python']
bad_lecturer.courses_attached += ['Введение']
bad_lecturer.courses_attached += ["Git"]

new_reviewer = Reviewer("Ozzy", "Osbourne")  # Проверяющий №1
new_reviewer.courses_attached += ['Python']
new_reviewer.courses_attached += ['Введение']

new_reviewer.rate_hw(best_student, "Python", 9)  # Ставим оценки студентам
new_reviewer.rate_hw(best_student, "Python", 7)
new_reviewer.rate_hw(best_student, "Введение", 8)
new_reviewer.rate_hw(worst_student, "Python", 4)
new_reviewer.rate_hw(worst_student, "Python", 5)
new_reviewer.rate_hw(worst_student, "Введение", 5)

best_student.rate_lecturer(cool_lecturer, "Python", 10)  # Ставим оценки лекторам
best_student.rate_lecturer(cool_lecturer, "Введение", 9)
best_student.rate_lecturer(cool_lecturer, "Python", 9)
best_student.rate_lecturer(bad_lecturer, "Python", 10)
best_student.rate_lecturer(bad_lecturer, "Введение", 9)
best_student.rate_lecturer(bad_lecturer, "Python", 8)

list_students = [best_student, worst_student]
list_lecturer = [cool_lecturer, bad_lecturer]
# ______________________________________________________________________________________________

def average_rate_students(lst, course):  # Средняя оценка всех студентов в рамках курса
    all_grades = []
    for student in lst:
        for key, value in student.grades.items():
            if key == course:
                for grade in value:
                    all_grades.append(grade)
    if not all_grades:
        return "Ошибка"
    else:
        return round((sum(all_grades) / len(all_grades)), 1)


def average_rate_lecturer(lst, course):  # Средняя оценка всех лекторов в рамках курса
    all_grades = []
    for lecturer in lst:
        for key, value in lecturer.grades.items():
            if key == course:
                for grade in value:
                    all_grades.append(grade)
    if not all_grades:
        return "Ошибка"
    else:
        return round((sum(all_grades) / len(all_grades)), 1)


print('\nПроверим участников\n')
print(*list_students, sep='\n\n')
print('-' * 20)
print(*list_lecturer, sep='\n\n')
print('-' * 20)

print('\nПроверка пользователей после получения оценок')
print('-' * 20)
print(bad_lecturer > cool_lecturer)
print(worst_student > best_student)
print(worst_student == best_student)
print('-' * 20)

print("\nСредняя оценка студентов по Python", + average_rate_students(list_students, 'Python'))
print("\nСредняя оценка лекторов по Python", + average_rate_lecturer(list_lecturer, 'Python'))
# Out:
# Проверим участников
#
# Имя: Mick
# Фамилия: Jagger
# Средняя оценка за домашние задания: 8.0
# Курсы в процессе изучения: ['Python', 'Введение']
# Завершенные курсы: ['Git']
#
# Имя: Marilyn
# Фамилия: Manson
# Средняя оценка за домашние задания: 4.67
# Курсы в процессе изучения: ['Python', 'Введение']
# Завершенные курсы: ['Git']
# --------------------
# Имя: Till
# Фамилия: Lindemann
# Средняя оценка за лекции: 9.33
#
# Имя: Kurt
# Фамилия: Cobain
# Средняя оценка за лекции: 9.0
# --------------------
#
# Проверка пользователей после получения оценок
# --------------------
# False
# False
# False
# --------------------
#
# Средняя оценка студентов по Python 6.2
#
# Средняя оценка лекторов по Python 9.2
